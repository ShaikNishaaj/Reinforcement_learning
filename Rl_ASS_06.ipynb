# %% [markdown]
# <a href="https://colab.research.google.com/github/ShaikNishaaj/Reinforcement_learning/blob/main/Rl_ASS_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gymnasium

# %%
# !pip install gymnasium[toy_text]
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 81.8 MB/s eta 0:00:00
# ...

# %%
import gymnasium as gym
import numpy as np

# %%
def run_random_agent(env_name, episodes=5):
    env = gym.make(env_name, render_mode=None)
    print(f"\nRunning Random Agent in {env_name} environment")
    rewards = []

    for episode in range(episodes):
        state, info = env.reset()
        done = False
        total_reward = 0

        while not done:
            action = env.action_space.sample()
            next_state, reward, terminated, truncated, info = env.step(action)
            total_reward += reward
            state = next_state
            done = terminated or truncated

        rewards.append(total_reward)
        print(f"Episode {episode+1}: Total Reward = {total_reward}")

    avg_reward = np.mean(rewards)
    print(f"\nAverage Reward over {episodes} episodes in {env_name}: {avg_reward:.2f}")
    env.close()

# %%
run_random_agent("CliffWalking-v1", episodes=5)
# Out:
# Running Random Agent in CliffWalking-v1 environment
# Episode 1: Total Reward = -38015
# Episode 2: Total Reward = -97988
# Episode 3: Total Reward = -43325
# Episode 4: Total Reward = -28357
# Episode 5: Total Reward = -2657
#
# Average Reward over 5 episodes in CliffWalking-v1: -42068.40

# %%
run_random_agent("Taxi-v4", episodes=5)
# Out:
# Running Random Agent in Taxi-v4 environment
# Episode 1: Total Reward = -767
# Episode 2: Total Reward = -794
# Episode 3: Total Reward = -803
# Episode 4: Total Reward = -722
# Episode 5: Total Reward = -722
#
# Average Reward over 5 episodes in Taxi-v4: -761.60
